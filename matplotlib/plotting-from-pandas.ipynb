# %% [markdown]
# ### Plotting from pandas DataFrame

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
car_data = pd.read_csv("assets/car-sales.csv")
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
day_period = 30
ts = pd.Series(np.exp(np.linspace(0,5,num=day_period)), index=pd.date_range('1/1/2024', periods=day_period))
ts.plot()
ts.head()
# Out:
# 2024-01-01    1.000000
# 2024-01-02    1.188169
# 2024-01-03    1.411746
# 2024-01-04    1.677394
# 2024-01-05    1.993028
# Freq: D, dtype: float64

# %%
day_period = 100
ts = pd.Series(np.random.randn(day_period), index=pd.date_range('1/1/2024', periods=day_period))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### PLot using Pandas DataFrame

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_data["Price"]=car_data['Price'].str.replace("[$,.]", '', regex=True).str[:-2].astype(int)
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_data["Sale Date"] = pd.date_range("1/1/2024", periods=len(car_data))

car_data["Total Sales"] = car_data["Price"].cumsum()
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_data.plot(x="Sale Date", y="Total Sales", kind="line")
# Out:
# <Axes: xlabel='Sale Date'>

# %%
car_data.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
x = np.random.rand(10, 4)
x
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.322761  0.979651  0.595893  0.334603
# 1  0.318423  0.488734  0.338070  0.715980
# 2  0.003685  0.778693  0.914906  0.747931
# 3  0.649169  0.572277  0.805032  0.843588
# 4  0.720157  0.549160  0.479860  0.595105
# 5  0.396135  0.293236  0.069547  0.627788
# 6  0.572002  0.953661  0.616901  0.230982
# 7  0.609607  0.776704  0.865793  0.819695
# 8  0.345845  0.430634  0.038299  0.344299
# 9  0.505970  0.244666  0.475330  0.403042

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
car_data.plot(x="Make", y="Price", kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
car_data["Odometer (KM)"].plot( kind="hist", bins=10)
# Out:
# <Axes: ylabel='Frequency'>
