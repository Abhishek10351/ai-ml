# %% [markdown]
# ### Add different types of plots in matplotlib (mainly using numpy arrays)

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1000, 100)
y = np.square(x)

# %% [markdown]
# ### Different types of plots:

# %%
# Line plot
fig, ax = plt.subplots()
ax.plot(x, y)

# %%
 # Scatter plot
fig, ax = plt.subplots()
ax.scatter(x, y)

# %%
# Bar plot
fig, ax = plt.subplots()
prices = {'apple': 1.99, 'banana': 0.99, 'orange': 1.49}
ax.bar(prices.keys(), prices.values())
ax.set(ylabel='Price', title='Fruit prices', ylim=[0, 2])

# %%
# Horizontal bar plot
fig, ax = plt.subplots()
ax.barh(list(prices.keys()), list(prices.values()))
ax.set(xlabel='Price', title='Fruit prices', xlim=[0, 2])

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x, bins=40)

# %% [markdown]
# ### Subplots

# %%
# Subplots

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))
x1 = np.linspace(0, 1000, 100)
x2 = np.random.randn(100)

ax1.plot(x1, np.square(x1))
ax2.scatter(np.random.random(30), np.random.random(30))
ax3.bar(prices.keys(), prices.values())
ax4.hist(x2, bins=40)

# %%
# Subplots option 2
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
x1 = np.linspace(0, 1000, 100)
x2 = np.random.randn(100)

ax[0, 0].plot(x1, np.square(x1))
ax[0, 1].scatter(np.random.random(30), np.random.random(30))
ax[1, 0].bar(prices.keys(), prices.values())
ax[1, 1].hist(x2, bins=40)
# Out:
# (array([2., 1., 0., 0., 1., 0., 2., 0., 3., 5., 2., 0., 2., 8., 6., 3., 5.,
#         3., 5., 4., 5., 3., 4., 4., 4., 3., 7., 1., 2., 2., 2., 0., 3., 4.,
#         0., 0., 2., 0., 1., 1.]),
#  array([-2.31352784, -2.20107542, -2.08862299, -1.97617056, -1.86371813,
#         -1.75126571, -1.63881328, -1.52636085, -1.41390843, -1.301456  ,
#         -1.18900357, -1.07655114, -0.96409872, -0.85164629, -0.73919386,
#         -0.62674143, -0.51428901, -0.40183658, -0.28938415, -0.17693173,
#         -0.0644793 ,  0.04797313,  0.16042556,  0.27287798,  0.38533041,
#          0.49778284,  0.61023527,  0.72268769,  0.83514012,  0.94759255,
#          1.06004498,  1.1724974 ,  1.28494983,  1.39740226,  1.50985468,
#          1.62230711,  1.73475954,  1.84721197,  1.95966439,  2.07211682,
#          2.18456925]),
#  <BarContainer object of 40 artists>)
