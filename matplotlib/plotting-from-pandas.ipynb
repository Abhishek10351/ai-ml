# %% [markdown]
# ### Plotting from pandas DataFrame

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
car_data = pd.read_csv("assets/car-sales.csv")
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
day_period = 30
ts = pd.Series(np.exp(np.linspace(0,5,num=day_period)), index=pd.date_range('1/1/2024', periods=day_period))
ts.plot()
ts.head()
# Out:
# 2024-01-01    1.000000
# 2024-01-02    1.188169
# 2024-01-03    1.411746
# 2024-01-04    1.677394
# 2024-01-05    1.993028
# Freq: D, dtype: float64

# %%
day_period = 100
ts = pd.Series(np.random.randn(day_period), index=pd.date_range('1/1/2024', periods=day_period))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >
